# %%
import numpy as np
import random
import cv2
import os
from imutils import paths
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
from tensorflow.keras import backend as K

# %%
from fl_mnist_implementation_tutorial_utils import *

# %%
def load(paths, verbose=-1):
    '''expects images for each class in seperate dir, 
    e.g all digits in 0 class in the directory named 0 '''
    data = list()
    labels = list()
    # loop over the input images
    for (i, imgpath) in enumerate(paths):
        # load the image and extract the class labels
        im_gray = cv2.imread(imgpath, cv2.IMREAD_GRAYSCALE)
        image = np.array(im_gray).flatten()
        label = imgpath.split(os.path.sep)[-2]
        # scale the image to [0, 1] and add to list
        data.append(image/255)
        labels.append(label)
        # show an update every `verbose` images
        if verbose > 0 and i > 0 and (i + 1) % verbose == 0:
            print("[INFO] processed {}/{}".format(i + 1, len(paths)))
    # return a tuple of the data and labels
    return data, labels

# %%
#declear path to your mnist data folder
img_path = r'C:\Users\USER\CSE 711 Project\trainingSet\trainingSet'

#get the path list using the path object
image_paths = list(paths.list_images(img_path))

#apply our function
image_list, label_list = load(image_paths, verbose=10000)

#binarize the labels
lb = LabelBinarizer()
label_list = lb.fit_transform(label_list)

#split data into training and test set
X_train, X_test, y_train, y_test = train_test_split(image_list, 
                                                    label_list, 
                                                    test_size=0.1, 
                                                    random_state=42)
# Out:
# [INFO] processed 10000/42000
# [INFO] processed 20000/42000
# [INFO] processed 30000/42000
# [INFO] processed 40000/42000

# %%
def create_clients(image_list, label_list, num_clients=10, initial='clients'):
    ''' return: a dictionary with keys clients' names and value as 
                data shards - tuple of images and label lists.
        args: 
            image_list: a list of numpy arrays of training images
            label_list:a list of binarized labels for each image
            num_client: number of fedrated members (clients)
            initials: the clients'name prefix, e.g, clients_1 
            
    '''

    #create a list of client names
    client_names = ['{}_{}'.format(initial, i+1) for i in range(num_clients)]

    #randomize the data
    data = list(zip(image_list, label_list))
    random.shuffle(data)

    #shard data and place at each client
    size = len(data)//num_clients
    shards = [data[i:i + size] for i in range(0, size*num_clients, size)]

    #number of clients must equal number of shards
    assert(len(shards) == len(client_names))

    return {client_names[i] : shards[i] for i in range(len(client_names))}

# %%
#create clients
clients = create_clients(X_train, y_train, num_clients=10, initial='client')

# %%
def batch_data(data_shard, bs=32):
    '''Takes in a clients data shard and create a tfds object off it
    args:
        shard: a data, label constituting a client's data shard
        bs:batch size
    return:
        tfds object'''
    #seperate shard into data and labels lists
    data, label = zip(*data_shard)
    dataset = tf.data.Dataset.from_tensor_slices((list(data), list(label)))
    return dataset.shuffle(len(label)).batch(bs)

# %%
#process and batch the training data for each client
clients_batched = dict()
for (client_name, data) in clients.items():
    clients_batched[client_name] = batch_data(data)
    
#process and batch the test set  
test_batched = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(len(y_test))

# %%
class SimpleMLP:
    @staticmethod
    def build(shape, classes):
        model = Sequential()
        model.add(Dense(200,input_shape=(shape,)))
        model.add(Activation("relu"))
        model.add(Dense(200))
        model.add(Activation("relu"))
        model.add(Dense(classes))
        model.add(Activation("softmax"))
        return model

# %%
lr = 0.01 
comms_round = 100
loss='categorical_crossentropy'
metrics = ['accuracy']
optimizer = SGD(learning_rate=lr, 
                decay=lr / comms_round, 
                momentum=0.9
               )

# %%
#initialize global model
smlp_global = SimpleMLP()
global_model = smlp_global.build(784, 10)
        
#commence global training loop
for comm_round in range(comms_round):
            
    # get the global model's weights - will serve as the initial weights for all local models
    global_weights = global_model.get_weights()
    
    #initial list to collect local model weights after scalling
    scaled_local_weight_list = list()

    #randomize client data - using keys
    client_names= list(clients_batched.keys())
    random.shuffle(client_names)
    
    #loop through each client and create new local model
    for client in client_names:
        smlp_local = SimpleMLP()
        local_model = smlp_local.build(784, 10)
        local_model.compile(loss=loss, 
                      optimizer=optimizer, 
                      metrics=metrics)
        
        #set local model weight to the weight of the global model
        local_model.set_weights(global_weights)
        
        #fit local model with client's data
        local_model.fit(clients_batched[client], epochs=1, verbose=0)
        
        #scale the model weights and add to list
        scaling_factor = weight_scalling_factor(clients_batched, client)
        scaled_weights = scale_model_weights(local_model.get_weights(), scaling_factor)
        scaled_local_weight_list.append(scaled_weights)
        
        #clear session to free memory after each communication round
        K.clear_session()
        
    #to get the average over all the local model, we simply take the sum of the scaled weights
    average_weights = sum_scaled_weights(scaled_local_weight_list)
    
    #update global model 
    global_model.set_weights(average_weights)

    #test global model and print out metrics after each communications round
    for(X_test, y_test) in test_batched:
        global_acc, global_loss = test_model(X_test, y_test, global_model, comm_round)
# Out:
# comm_round: 0 | global_acc: 88.786% | global_loss: 1.6649059057235718
# comm_round: 1 | global_acc: 90.976% | global_loss: 1.6149927377700806
# comm_round: 2 | global_acc: 91.762% | global_loss: 1.5970388650894165
# comm_round: 3 | global_acc: 92.405% | global_loss: 1.5854429006576538
# comm_round: 4 | global_acc: 92.476% | global_loss: 1.576922059059143
# comm_round: 5 | global_acc: 93.262% | global_loss: 1.5696436166763306
# comm_round: 6 | global_acc: 93.881% | global_loss: 1.563057780265808
# comm_round: 7 | global_acc: 94.405% | global_loss: 1.5584033727645874
# comm_round: 8 | global_acc: 94.310% | global_loss: 1.5549397468566895
# comm_round: 9 | global_acc: 94.452% | global_loss: 1.551551342010498
# comm_round: 10 | global_acc: 94.976% | global_loss: 1.5477232933044434
# comm_round: 11 | global_acc: 95.095% | global_loss: 1.5459187030792236
# comm_round: 12 | global_acc: 94.952% | global_loss: 1.5433892011642456
# comm_round: 13 | global_acc: 95.024% | global_loss: 1.5418668985366821
# comm_round: 14 | global_acc: 95.405% | global_loss: 1.53935968875885
# comm_round: 15 | global_acc: 95.524% | global_loss: 1.538027048110962
# comm_round: 16 | global_acc: 95.548% | global_loss: 1.5363281965255737
# comm_round: 17 | global_acc: 95.571% | global_loss: 1.5350801944732666
# comm_round: 18 | global_acc: 95.524% | global_loss: 1.5336241722106934
# comm_round: 19 | global_acc: 95.714% | global_loss: 1.5323243141174316
# comm_round: 20 | global_acc: 95.667% | global_loss: 1.531611680984497
# comm_round: 21 | global_acc: 95.833% | global_loss: 1.5303152799606323
# comm_round: 22 | global_acc: 95.810% | global_loss: 1.529424786567688
# comm_round: 23 | global_acc: 95.833% | global_loss: 1.5286442041397095
# comm_round: 24 | global_acc: 95.810% | global_loss: 1.5279903411865234
# comm_round: 25 | global_acc: 95.929% | global_loss: 1.5269910097122192
# comm_round: 26 | global_acc: 95.881% | global_loss: 1.5261818170547485
# comm_round: 27 | global_acc: 95.976% | global_loss: 1.5258585214614868
# comm_round: 28 | global_acc: 96.024% | global_loss: 1.5251917839050293
# comm_round: 29 | global_acc: 96.024% | global_loss: 1.524470329284668
# comm_round: 30 | global_acc: 96.048% | global_loss: 1.5241820812225342
# comm_round: 31 | global_acc: 96.071% | global_loss: 1.5234915018081665
# comm_round: 32 | global_acc: 96.143% | global_loss: 1.52293062210083
# comm_round: 33 | global_acc: 96.024% | global_loss: 1.5224730968475342
# comm_round: 34 | global_acc: 96.000% | global_loss: 1.5218827724456787
# comm_round: 35 | global_acc: 96.143% | global_loss: 1.5218299627304077
# comm_round: 36 | global_acc: 96.048% | global_loss: 1.5211045742034912
# comm_round: 37 | global_acc: 96.143% | global_loss: 1.520858645439148
# comm_round: 38 | global_acc: 96.190% | global_loss: 1.520341396331787
# comm_round: 39 | global_acc: 96.119% | global_loss: 1.5200142860412598
# comm_round: 40 | global_acc: 96.143% | global_loss: 1.5196772813796997
# comm_round: 41 | global_acc: 96.190% | global_loss: 1.5191867351531982
# comm_round: 42 | global_acc: 96.143% | global_loss: 1.518898367881775
# comm_round: 43 | global_acc: 96.286% | global_loss: 1.518410325050354
# comm_round: 44 | global_acc: 96.190% | global_loss: 1.5183131694793701
# comm_round: 45 | global_acc: 96.238% | global_loss: 1.5179389715194702
# comm_round: 46 | global_acc: 96.286% | global_loss: 1.5179026126861572
# comm_round: 47 | global_acc: 96.286% | global_loss: 1.5173178911209106
# comm_round: 48 | global_acc: 96.262% | global_loss: 1.517200231552124
# comm_round: 49 | global_acc: 96.262% | global_loss: 1.5172407627105713
# comm_round: 50 | global_acc: 96.310% | global_loss: 1.5167244672775269
# comm_round: 51 | global_acc: 96.262% | global_loss: 1.5165742635726929
# comm_round: 52 | global_acc: 96.262% | global_loss: 1.516319990158081
# comm_round: 53 | global_acc: 96.310% | global_loss: 1.5161105394363403
# comm_round: 54 | global_acc: 96.333% | global_loss: 1.5158663988113403
# comm_round: 55 | global_acc: 96.310% | global_loss: 1.5155590772628784
# comm_round: 56 | global_acc: 96.357% | global_loss: 1.5152424573898315
# comm_round: 57 | global_acc: 96.286% | global_loss: 1.515038013458252
# comm_round: 58 | global_acc: 96.357% | global_loss: 1.5149914026260376
# comm_round: 59 | global_acc: 96.310% | global_loss: 1.5146782398223877
# comm_round: 60 | global_acc: 96.310% | global_loss: 1.5145920515060425
# comm_round: 61 | global_acc: 96.262% | global_loss: 1.5144912004470825
# comm_round: 62 | global_acc: 96.357% | global_loss: 1.514375925064087
# comm_round: 63 | global_acc: 96.381% | global_loss: 1.5139741897583008
# comm_round: 64 | global_acc: 96.286% | global_loss: 1.513932466506958
# comm_round: 65 | global_acc: 96.405% | global_loss: 1.513946533203125
# comm_round: 66 | global_acc: 96.429% | global_loss: 1.5136210918426514
# comm_round: 67 | global_acc: 96.381% | global_loss: 1.513307809829712
# comm_round: 68 | global_acc: 96.452% | global_loss: 1.5131950378417969
# comm_round: 69 | global_acc: 96.429% | global_loss: 1.513076901435852
# comm_round: 70 | global_acc: 96.476% | global_loss: 1.5130648612976074
# comm_round: 71 | global_acc: 96.476% | global_loss: 1.512884497642517
# comm_round: 72 | global_acc: 96.429% | global_loss: 1.5126843452453613
# comm_round: 73 | global_acc: 96.452% | global_loss: 1.51274573802948
# comm_round: 74 | global_acc: 96.452% | global_loss: 1.5123326778411865
# comm_round: 75 | global_acc: 96.476% | global_loss: 1.5122488737106323
# comm_round: 76 | global_acc: 96.429% | global_loss: 1.512215256690979
# comm_round: 77 | global_acc: 96.571% | global_loss: 1.5117912292480469
# comm_round: 78 | global_acc: 96.476% | global_loss: 1.5118266344070435
# comm_round: 79 | global_acc: 96.500% | global_loss: 1.5117114782333374
# comm_round: 80 | global_acc: 96.619% | global_loss: 1.5115832090377808
# comm_round: 81 | global_acc: 96.524% | global_loss: 1.5115342140197754
# comm_round: 82 | global_acc: 96.571% | global_loss: 1.5114953517913818
# comm_round: 83 | global_acc: 96.476% | global_loss: 1.5112481117248535
# comm_round: 84 | global_acc: 96.595% | global_loss: 1.5110366344451904
# comm_round: 85 | global_acc: 96.524% | global_loss: 1.5111857652664185
# comm_round: 86 | global_acc: 96.595% | global_loss: 1.5108850002288818
# comm_round: 87 | global_acc: 96.619% | global_loss: 1.5108938217163086
# comm_round: 88 | global_acc: 96.619% | global_loss: 1.5107892751693726
# comm_round: 89 | global_acc: 96.524% | global_loss: 1.5108016729354858
# comm_round: 90 | global_acc: 96.619% | global_loss: 1.5107245445251465
# comm_round: 91 | global_acc: 96.595% | global_loss: 1.5105136632919312
# comm_round: 92 | global_acc: 96.619% | global_loss: 1.5104409456253052
# comm_round: 93 | global_acc: 96.643% | global_loss: 1.5103226900100708
# comm_round: 94 | global_acc: 96.643% | global_loss: 1.5102392435073853
# comm_round: 95 | global_acc: 96.667% | global_loss: 1.5099622011184692
# comm_round: 96 | global_acc: 96.690% | global_loss: 1.5099867582321167
# comm_round: 97 | global_acc: 96.690% | global_loss: 1.509896159172058
# comm_round: 98 | global_acc: 96.690% | global_loss: 1.5098108053207397
# comm_round: 99 | global_acc: 96.667% | global_loss: 1.5098421573638916
