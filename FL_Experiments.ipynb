# %%
import numpy as np
import random
import cv2
import os
from imutils import paths
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
from tensorflow.keras import backend as K

# %%
from fl_mnist_implementation_utils import *

# %%
def load(paths, verbose=-1):
    '''expects images for each class in seperate dir, 
    e.g all digits in 0 class in the directory named 0 '''
    data = list()
    labels = list()
    # loop over the input images
    for (i, imgpath) in enumerate(paths):
        # load the image and extract the class labels
        im_gray = cv2.imread(imgpath, cv2.IMREAD_GRAYSCALE)
        #image = np.array(im_gray).flatten()
        label = imgpath.split(os.path.sep)[-2]
        # scale the image to [0, 1] and add to list
        data.append(im_gray/255)
        labels.append(label)
        # show an update every `verbose` images
        if verbose > 0 and i > 0 and (i + 1) % verbose == 0:
            print("[INFO] processed {}/{}".format(i + 1, len(paths)))
    # return a tuple of the data and labels
    return data, labels

# %%
#declear path to your mnist data folder
img_path = r'C:\Users\USER\CSE 711 Project\trainingSet\trainingSet'

#get the path list using the path object
image_paths = list(paths.list_images(img_path))

#apply our function
image_list, label_list = load(image_paths, verbose=10000)

#binarize the labels
lb = LabelBinarizer()
label_list = lb.fit_transform(label_list)

#split data into training and test set
X_train, X_test, y_train, y_test = train_test_split(image_list, 
                                                    label_list, 
                                                    test_size=0.1, 
                                                    random_state=42)
# Out:
# [INFO] processed 10000/42000
# [INFO] processed 20000/42000
# [INFO] processed 30000/42000
# [INFO] processed 40000/42000

# %%
def create_clients(image_list, label_list, num_clients=10, initial='clients'):
    ''' return: a dictionary with keys clients' names and value as 
                data shards - tuple of images and label lists.
        args: 
            image_list: a list of numpy arrays of training images
            label_list:a list of binarized labels for each image
            num_client: number of fedrated members (clients)
            initials: the clients'name prefix, e.g, clients_1 
            
    '''

    #create a list of client names
    client_names = ['{}_{}'.format(initial, i+1) for i in range(num_clients)]

    #randomize the data
    data = list(zip(image_list, label_list))
    random.shuffle(data)

    #shard data and place at each client
    size = len(data)//num_clients
    shards = [data[i:i + size] for i in range(0, size*num_clients, size)]

    #number of clients must equal number of shards
    assert(len(shards) == len(client_names))

    return {client_names[i] : shards[i] for i in range(len(client_names))}

# %%
#create clients
clients = create_clients(X_train, y_train, num_clients=10, initial='client')

# %%
def batch_data(data_shard, bs=32):
    '''Takes in a clients data shard and create a tfds object off it
    args:
        shard: a data, label constituting a client's data shard
        bs:batch size
    return:
        tfds object'''
    #seperate shard into data and labels lists
    data, label = zip(*data_shard)
    dataset = tf.data.Dataset.from_tensor_slices((list(data), list(label)))
    return dataset.shuffle(len(label)).batch(bs)

# %%
#process and batch the training data for each client
clients_batched = dict()
for (client_name, data) in clients.items():
    clients_batched[client_name] = batch_data(data)
    
#process and batch the test set  
test_batched = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(len(y_test))

# %%
class SimpleMLP:
    @staticmethod
    def build(shape, classes):
        model = Sequential()
        model.add(Conv2D(32, (3,3), input_shape=shape))
        model.add(Activation("relu"))
        model.add(MaxPooling2D(2,2))
        model.add(Conv2D(64, (3,3)))
        model.add(Activation("relu"))
        model.add(MaxPooling2D(2,2))
        model.add(Flatten())
        model.add(Dense(256))
        model.add(Activation("relu"))
        model.add(Dense(classes))
        model.add(Activation("softmax"))
        return model

# %%
lr = 0.01 
comms_round = 100
loss='categorical_crossentropy'
metrics = ['accuracy']
optimizer = SGD(learning_rate=lr, 
                decay=lr / comms_round, 
                momentum=0.9
               )

# %%
#initialize global model
smlp_global = SimpleMLP()
global_model = smlp_global.build((28, 28, 1), 10)
        
#commence global training loop
for comm_round in range(comms_round):
            
    # get the global model's weights - will serve as the initial weights for all local models
    global_weights = global_model.get_weights()
    
    #initial list to collect local model weights after scalling
    scaled_local_weight_list = list()

    #randomize client data - using keys
    client_names= list(clients_batched.keys())
    random.shuffle(client_names)
    
    #loop through each client and create new local model
    for client in client_names:
        smlp_local = SimpleMLP()
        local_model = smlp_local.build((28, 28, 1), 10)
        local_model.compile(loss=loss, 
                      optimizer=optimizer, 
                      metrics=metrics)
        
        #set local model weight to the weight of the global model
        local_model.set_weights(global_weights)
        
        #fit local model with client's data
        local_model.fit(clients_batched[client], epochs=1, verbose=0)
        
        #scale the model weights and add to list
        scaling_factor = weight_scalling_factor(clients_batched, client)
        scaled_weights = scale_model_weights(local_model.get_weights(), scaling_factor)
        scaled_local_weight_list.append(scaled_weights)
        
        #clear session to free memory after each communication round
        K.clear_session()
        
    #to get the average over all the local model, we simply take the sum of the scaled weights
    average_weights = sum_scaled_weights(scaled_local_weight_list)
    
    #update global model 
    global_model.set_weights(average_weights)

    #test global model and print out metrics after each communications round
    for(X_test, y_test) in test_batched:
        global_acc, global_loss = test_model(X_test, y_test, global_model, comm_round)
# Out:
# comm_round: 0 | global_acc: 91.571% | global_loss: 1.603344202041626
# comm_round: 1 | global_acc: 94.786% | global_loss: 1.5464863777160645
# comm_round: 2 | global_acc: 96.167% | global_loss: 1.5260276794433594
# comm_round: 3 | global_acc: 96.333% | global_loss: 1.516903042793274
# comm_round: 4 | global_acc: 97.262% | global_loss: 1.5088359117507935
# comm_round: 5 | global_acc: 97.405% | global_loss: 1.5049782991409302
# comm_round: 6 | global_acc: 97.429% | global_loss: 1.5024563074111938
# comm_round: 7 | global_acc: 97.643% | global_loss: 1.4999431371688843
# comm_round: 8 | global_acc: 97.738% | global_loss: 1.49672532081604
# comm_round: 9 | global_acc: 97.905% | global_loss: 1.4950268268585205
# comm_round: 10 | global_acc: 98.071% | global_loss: 1.4935128688812256
# comm_round: 11 | global_acc: 97.881% | global_loss: 1.4935662746429443
# comm_round: 12 | global_acc: 98.095% | global_loss: 1.4917263984680176
# comm_round: 13 | global_acc: 98.167% | global_loss: 1.4909456968307495
# comm_round: 14 | global_acc: 98.095% | global_loss: 1.490678310394287
# comm_round: 15 | global_acc: 98.143% | global_loss: 1.4898390769958496
# comm_round: 16 | global_acc: 98.167% | global_loss: 1.4890609979629517
# comm_round: 17 | global_acc: 98.286% | global_loss: 1.4883973598480225
# comm_round: 59 | global_acc: 98.714% | global_loss: 1.479917287826538
# comm_round: 60 | global_acc: 98.690% | global_loss: 1.4800082445144653
# comm_round: 61 | global_acc: 98.595% | global_loss: 1.4800422191619873
# comm_round: 62 | global_acc: 98.738% | global_loss: 1.4799280166625977
# comm_round: 63 | global_acc: 98.667% | global_loss: 1.4798798561096191
# comm_round: 64 | global_acc: 98.690% | global_loss: 1.479613184928894
# comm_round: 65 | global_acc: 98.690% | global_loss: 1.4796305894851685
# comm_round: 66 | global_acc: 98.690% | global_loss: 1.479677677154541
# comm_round: 67 | global_acc: 98.690% | global_loss: 1.4795664548873901
# comm_round: 68 | global_acc: 98.667% | global_loss: 1.4794933795928955
# comm_round: 69 | global_acc: 98.714% | global_loss: 1.479404091835022
# comm_round: 70 | global_acc: 98.690% | global_loss: 1.479309320449829
# comm_round: 71 | global_acc: 98.690% | global_loss: 1.4792433977127075
# comm_round: 72 | global_acc: 98.714% | global_loss: 1.4790908098220825
# comm_round: 73 | global_acc: 98.690% | global_loss: 1.479507565498352
# comm_round: 74 | global_acc: 98.738% | global_loss: 1.479019045829773
# comm_round: 75 | global_acc: 98.738% | global_loss: 1.4792252779006958
# comm_round: 76 | global_acc: 98.762% | global_loss: 1.4789625406265259
# comm_round: 77 | global_acc: 98.690% | global_loss: 1.4789265394210815
# comm_round: 78 | global_acc: 98.714% | global_loss: 1.4788740873336792
# comm_round: 79 | global_acc: 98.762% | global_loss: 1.4788540601730347
# comm_round: 80 | global_acc: 98.762% | global_loss: 1.478967547416687
# comm_round: 81 | global_acc: 98.738% | global_loss: 1.4789389371871948
# comm_round: 82 | global_acc: 98.738% | global_loss: 1.4787532091140747
# comm_round: 83 | global_acc: 98.738% | global_loss: 1.4788867235183716
# comm_round: 84 | global_acc: 98.762% | global_loss: 1.4785568714141846
# comm_round: 85 | global_acc: 98.714% | global_loss: 1.4786758422851562
# comm_round: 86 | global_acc: 98.762% | global_loss: 1.4786994457244873
# comm_round: 87 | global_acc: 98.786% | global_loss: 1.478592872619629
# comm_round: 88 | global_acc: 98.786% | global_loss: 1.478550910949707
# comm_round: 89 | global_acc: 98.810% | global_loss: 1.4784767627716064
# comm_round: 90 | global_acc: 98.762% | global_loss: 1.4785853624343872
# comm_round: 91 | global_acc: 98.786% | global_loss: 1.4783860445022583
# comm_round: 92 | global_acc: 98.810% | global_loss: 1.478459358215332
# comm_round: 93 | global_acc: 98.810% | global_loss: 1.4782603979110718
# comm_round: 94 | global_acc: 98.786% | global_loss: 1.4782875776290894
# comm_round: 95 | global_acc: 98.786% | global_loss: 1.4783962965011597
# comm_round: 96 | global_acc: 98.810% | global_loss: 1.4782202243804932
# comm_round: 97 | global_acc: 98.810% | global_loss: 1.478327989578247
# comm_round: 98 | global_acc: 98.810% | global_loss: 1.4780972003936768
# comm_round: 99 | global_acc: 98.810% | global_loss: 1.4782721996307373
